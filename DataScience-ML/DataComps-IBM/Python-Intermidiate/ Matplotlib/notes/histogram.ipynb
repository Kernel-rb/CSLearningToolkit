# %%
# histogram est tres utile pour explorer la data et voir la distribution de la data

# %%
import matplotlib.pyplot as plt
values  = [0,0.6,1.4 ,1.6,2.2,2.8,3.0,3.1,3.8,4.4,6]
plt.hist(values, bins=3)
plt.show()
